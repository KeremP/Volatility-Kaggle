# %% [markdown]
# # XGB Baseline

# %% [markdown]
# This notebook offers:
#
# - first iteration of feature engineering (more to come)
# - baseline XGB training & prediction scores
#
# Credits to:
# - https://www.kaggle.com/manels/lgb-starter

# %%
import os, gc
import glob

from tqdm.notebook import tqdm
import pandas as pd
import numpy as np

from joblib import Parallel, delayed
from sklearn import preprocessing, model_selection

import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb

# %matplotlib inline

# %%
path_root = "./"
path_data = "./"

path_submissions = "./"

target_name = 'target'

# %%
train = pd.read_csv(os.path.join(path_data, 'train.csv'))

# %%
train.head()
# Out:
#    stock_id  time_id    target
# 0         0        5  0.004136
# 1         0       11  0.001445
# 2         0       16  0.002168
# 3         0       31  0.002195
# 4         0       62  0.001747

# %%
test = pd.read_csv(os.path.join(path_data,'test.csv'))

# %%
test.head()
# Out:
#    stock_id  time_id row_id
# 0         0        4    0-4
# 1         0       32   0-32
# 2         0       34   0-34

# %%
def log_return(list_stock_prices):
    return np.log(list_stock_prices).diff() 

def realized_volatility(series_log_return):
    return np.sqrt(np.sum(series_log_return**2))

def rmspe(y_true, y_pred):
    return (np.sqrt(np.mean(np.square((y_true - y_pred)/y_true))))

# %%
def get_stock_stat(stock_id : int, dataType = 'train'):
    key = ['stock_id', 'time_id', 'seconds_in_bucket']
    
    #Book features
    df_book = pd.read_parquet(os.path.join(path_data, 'book_{}.parquet/stock_id={}/'.format(dataType, stock_id)))
    df_book['stock_id'] = stock_id
    cols = key + [col for col in df_book.columns if col not in key]
    df_book = df_book[cols]
    
    df_book['wap1'] = (df_book['bid_price1'] * df_book['ask_size1'] +
                                    df_book['ask_price1'] * df_book['bid_size1']) / (df_book['bid_size1'] + df_book['ask_size1'])
    df_book['wap2'] = (df_book['bid_price2'] * df_book['ask_size2'] +
                                    df_book['ask_price2'] * df_book['bid_size2']) / (df_book['bid_size2'] + df_book['ask_size2'])
    df_book['log_return1'] = df_book.groupby(by = ['time_id'])['wap1'].apply(log_return).fillna(0)
    df_book['log_return2'] = df_book.groupby(by = ['time_id'])['wap2'].apply(log_return).fillna(0)
    
    features_to_apply_realized_volatility = ['log_return'+str(i+1) for i in range(2)]
    stock_stat = df_book.groupby(by = ['stock_id', 'time_id'])[features_to_apply_realized_volatility]\
                        .agg(realized_volatility).reset_index()

    #Trade features
    trade_stat =  pd.read_parquet(os.path.join(path_data,'trade_{}.parquet/stock_id={}'.format(dataType, stock_id)))
    trade_stat = trade_stat.sort_values(by=['time_id', 'seconds_in_bucket']).reset_index(drop=True)
    trade_stat['stock_id'] = stock_id
    cols = key + [col for col in trade_stat.columns if col not in key]
    trade_stat = trade_stat[cols]
    trade_stat['trade_log_return1'] = trade_stat.groupby(by = ['time_id'])['price'].apply(log_return).fillna(0)
    trade_stat = trade_stat.groupby(by = ['stock_id', 'time_id'])[['trade_log_return1']]\
                           .agg(realized_volatility).reset_index()
    #Joining book and trade features
    stock_stat = stock_stat.merge(trade_stat, on=['stock_id', 'time_id'], how='left').fillna(-999)
    
    return stock_stat

def get_dataSet(stock_ids : list, dataType = 'train'):

    stock_stat = Parallel(n_jobs=-1)(
        delayed(get_stock_stat)(stock_id, dataType) 
        for stock_id in stock_ids
    )
    
    stock_stat_df = pd.concat(stock_stat, ignore_index = True)

    return stock_stat_df

# %%
def feval_RMSPE(preds, train_data):
    labels = train_data.get_label()
    return 'RMSPE', round(rmspe(y_true = labels, y_pred = preds),5), False

# %%
# %time train_stock_df = get_dataSet(stock_ids = train['stock_id'].unique(), 
                                  dataType='train')

train = pd.merge(train, train_stock_df, on=['stock_id','time_id'],how='left').fillna(0)
print(f'Train shape: {train.shape}')

#-------------------------------------------------------------------------------

test_stock_df = get_dataSet(stock_ids = test['stock_id'].unique(),
                           dataType='test')
test = pd.merge(test, test_stock_df, on=['stock_id','time_id'],how='left').fillna(0)
print(f'Test shape: {test.shape}')

test.head(2)
# Out:
# Train shape: (428932, 6)
# Test shape: (3, 6)
#    stock_id  time_id row_id  log_return1  log_return2  trade_log_return1
# 0         0        4    0-4     0.000294     0.000252           0.000295
# 1         0       32   0-32     0.000000     0.000000           0.000000

# %%
train.head(2)
# Out:
#    stock_id  time_id    target  log_return1  log_return2  trade_log_return1
# 0         0        5  0.004136     0.004499     0.006999           0.002006
# 1         0       11  0.001445     0.001204     0.002476           0.000901

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args

# modified code for group gaps; source
# https://github.com/getgaurav2/scikit-learn/blob/d4a3af5cc9da3a76f0266932644b884c99724c57/sklearn/model_selection/_split.py#L2243
class PurgedGroupTimeSeriesSplit(_BaseKFold):
    """Time Series cross-validator variant with non-overlapping groups.
    Allows for a gap in groups to avoid potentially leaking info from
    train into test if the model has windowed or lag features.
    Provides train/test indices to split time series data samples
    that are observed at fixed time intervals according to a
    third-party provided group.
    In each split, test indices must be higher than before, and thus shuffling
    in cross validator is inappropriate.
    This cross-validation object is a variation of :class:`KFold`.
    In the kth split, it returns first k folds as train set and the
    (k+1)th fold as test set.
    The same group will not appear in two different folds (the number of
    distinct groups has to be at least equal to the number of folds).
    Note that unlike standard cross-validation methods, successive
    training sets are supersets of those that come before them.
    Read more in the :ref:`User Guide <cross_validation>`.
    Parameters
    ----------
    n_splits : int, default=5
        Number of splits. Must be at least 2.
    max_train_group_size : int, default=Inf
        Maximum group size for a single training set.
    group_gap : int, default=None
        Gap between train and test
    max_test_group_size : int, default=Inf
        We discard this number of groups from the end of each train split
    """

    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_group_size=np.inf,
                 max_test_group_size=np.inf,
                 group_gap=None,
                 verbose=False
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_group_size = max_train_group_size
        self.group_gap = group_gap
        self.max_test_group_size = max_test_group_size
        self.verbose = verbose

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        group_gap = self.group_gap
        max_test_group_size = self.max_test_group_size
        max_train_group_size = self.max_train_group_size
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))

        group_test_size = min(n_groups // n_folds, max_test_group_size)
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []

            group_st = max(0, group_test_start - group_gap - max_train_group_size)
            for train_group_idx in unique_groups[group_st:(group_test_start - group_gap)]:
                train_array_tmp = group_dict[train_group_idx]
                
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)

            train_end = train_array.size
 
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)

            test_array  = test_array[group_gap:]
            
            
            if self.verbose > 0:
                    pass
                    
            yield [int(i) for i in train_array], [int(i) for i in test_array]

# %%
groupedKFold = PurgedGroupTimeSeriesSplit(n_splits=4, group_gap=12)
split = list(groupedKFold.split(train['target'],groups=train['time_id'].values))

# %%
cats = ['stock_id'] # must set "enable_categorial" param in XGB
model_name = 'xgb1'
pred_name = f'pred_{model_name}'
features = ['stock_id','log_return1','log_return2','trade_log_return1']
print(f'Considerding {len(features)} features')

train[pred_name] = 0
test['target'] = 0
cv_score = {}
cv_score[model_name] = []

for _fold, (tr,te) in enumerate(split):
    print(f'Fold: {_fold}')
    
    trainSet_X = train.iloc[tr][features]
    trainSet_Y = train.iloc[tr][target_name].values
    
    valSet_X = train.iloc[te][features]
    valSet_Y = train.iloc[te][target_name].values
    
    print(len(trainSet_X), len(valSet_Y))
    
    weights = (1/np.square(trainSet_Y))
    valWeights = (1/np.square(valSet_Y))
    params = {'tree_method':'gpu_hist','reg_alpha' : 20, 'reg_lambda' : 20, 'max_depth' : 5, 'n_estimators' : 500, 'verbosity': 3}
    model = xgb.XGBRegressor(**params)
    
    model.fit(trainSet_X, trainSet_Y,
             eval_set=[(valSet_X,valSet_Y)],
             early_stopping_rounds=10, sample_weight=weights,
              sample_weight_eval_set=[valWeights],verbose=True
             )
    print(f'Eval result: {model.evals_result()}')
    
    preds = model.predict(valSet_X)
    score = round(rmspe(valSet_Y,preds),5)
    cv_score[model_name].append(score)
    print(f'RMSPE Score: {score}')
# Out:
# Considerding 4 features
# Fold: 0
# 84445 85771
# [16:55:39] ======== Monitor: Learner ========
# [16:55:39] Configure: 0.002027s, 1 calls @ 2027us
#
# [16:55:39] ======== Monitor: GBTree ========
# [16:55:39] ======== Device 0 Memory Allocations:  ========
# [16:55:39] Peak memory usage: 40MiB
# [16:55:39] Number of allocations: 53964
# [16:55:39] ======== Monitor: updater_gpu_hist ========
# [16:55:39] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [16:55:39] ======== Monitor: SketchContainer ========
# [16:55:39] MakeCuts: 0.000939s, 1 calls @ 939us
#
# [16:55:39] Prune: 0.000592s, 1 calls @ 592us
#
# [16:55:39] ScanInput: 0.000493s, 1 calls @ 493us
#
# [16:55:39] Unique: 0.000405s, 1 calls @ 405us
#
# [0]	validation_0-rmse:0.34875
# [1]	validation_0-rmse:0.24413
# [2]	validation_0-rmse:0.17089
# [3]	validation_0-rmse:0.11962
# [4]	validation_0-rmse:0.08374
# [5]	validation_0-rmse:0.05862
# [6]	validation_0-rmse:0.04104
# [7]	validation_0-rmse:0.02873
# [8]	validation_0-rmse:0.02012
# [9]	validation_0-rmse:0.01409
# [10]	validation_0-rmse:0.00987
# [11]	validation_0-rmse:0.00692
# [12]	validation_0-rmse:0.00486
# [13]	validation_0-rmse:0.00343
# [14]	validation_0-rmse:0.00243
# [15]	validation_0-rmse:0.00175
# [16]	validation_0-rmse:0.00129
# [17]	validation_0-rmse:0.00098
# [18]	validation_0-rmse:0.00079
# [19]	validation_0-rmse:0.00068
# [20]	validation_0-rmse:0.00061
# [21]	validation_0-rmse:0.00058
# [22]	validation_0-rmse:0.00056
# [23]	validation_0-rmse:0.00055
# [24]	validation_0-rmse:0.00055
# [25]	validation_0-rmse:0.00055
# [26]	validation_0-rmse:0.00054
# [27]	validation_0-rmse:0.00054
# [28]	validation_0-rmse:0.00054
# [29]	validation_0-rmse:0.00054
# [30]	validation_0-rmse:0.00054
# [31]	validation_0-rmse:0.00054
# [32]	validation_0-rmse:0.00054
# [33]	validation_0-rmse:0.00054
# [34]	validation_0-rmse:0.00054
# [35]	validation_0-rmse:0.00054
# [36]	validation_0-rmse:0.00054
# [37]	validation_0-rmse:0.00054
# [38]	validation_0-rmse:0.00054
# [39]	validation_0-rmse:0.00054
# [40]	validation_0-rmse:0.00054
# [41]	validation_0-rmse:0.00054
# [16:55:40] ======== Monitor: Learner ========
# [16:55:40] Configure: 0.000423s, 1 calls @ 423us
#
# [16:55:40] EvalOneIter: 0.062681s, 43 calls @ 62681us
#
# [16:55:40] GetGradient: 0.007297s, 43 calls @ 7297us
#
# [16:55:40] PredictRaw: 0.000542s, 43 calls @ 542us
#
# [16:55:40] UpdateOneIter: 0.295865s, 43 calls @ 295865us
#
# [16:55:40] ======== Monitor: GBTree ========
# [16:55:40] BoostNewTrees: 0.279816s, 43 calls @ 279816us
#
# [16:55:40] CommitModel: 0.006517s, 43 calls @ 6517us
#
# [16:55:40] ======== Device 0 Memory Allocations:  ========
# [16:55:40] Peak memory usage: 40MiB
# [16:55:40] Number of allocations: 59208
# [16:55:40] ======== Monitor: updater_gpu_hist ========
# [16:55:40] InitData: 0.011712s, 43 calls @ 11712us
#
# [16:55:40] InitDataOnce: 0.011705s, 1 calls @ 11705us
#
# [16:55:40] Update: 0.279136s, 43 calls @ 279136us
#
# [16:55:40] UpdatePredictionCache: 0.006391s, 43 calls @ 6391us
#
# [16:55:40] ======== Monitor: gradient_based_sampler ========
# [16:55:40] Sample: 2.1e-05s, 43 calls @ 21us
#
# [16:55:40] ======== Monitor: GPUHistMakerDevice0 ========
# [16:55:40] AllReduce: 0.000129s, 663 calls @ 129us
#
# [16:55:40] BuildHist: 0.011617s, 620 calls @ 11617us
#
# [16:55:40] EvaluateSplits: 0.013794s, 620 calls @ 13794us
#
# [16:55:40] FinalisePosition: 0.003626s, 43 calls @ 3626us
#
# [16:55:40] InitRoot: 0.03959s, 43 calls @ 39590us
#
# [16:55:40] Reset: 0.024124s, 43 calls @ 24124us
#
# [16:55:40] UpdatePosition: 0.120939s, 620 calls @ 120939us
#
# [16:55:40] ======== Monitor: ellpack_page ========
# [16:55:40] BinningCompression: 0.002314s, 1 calls @ 2314us
#
# [16:55:40] InitCompressedData: 6.6e-05s, 1 calls @ 66us
#
# [16:55:40] Quantiles: 0.009151s, 1 calls @ 9151us
#
# Eval result: {'validation_0': OrderedDict([('rmse', [0.348755, 0.244127, 0.17089, 0.119624, 0.083738, 0.058619, 0.041037, 0.028731, 0.020117, 0.014089, 0.009872, 0.006924, 0.004864, 0.003429, 0.002434, 0.00175, 0.001287, 0.000983, 0.000792, 0.000678, 0.000614, 0.000579, 0.000562, 0.000553, 0.000549, 0.000546, 0.000544, 0.000544, 0.000543, 0.000543, 0.000543, 0.000543, 0.000542, 0.000542, 0.000542, 0.000543, 0.000542, 0.000542, 0.000543, 0.000543, 0.000543, 0.000543, 0.000543])])}
# [16:55:40] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [16:55:40] ======== Device 0 Memory Allocations:  ========
# [16:55:40] Peak memory usage: 40MiB
# [16:55:40] Number of allocations: 59208
# [16:55:40] ======== Monitor:  ========
# RMSPE Score: 0.2535
# Fold: 1
# 170227 85775
# [16:55:40] ======== Monitor: Learner ========
# [16:55:40] Configure: 0.001062s, 1 calls @ 1062us
#
# [16:55:40] ======== Monitor: GBTree ========
# [16:55:40] ======== Device 0 Memory Allocations:  ========
# [16:55:40] Peak memory usage: 40MiB
# [16:55:40] Number of allocations: 59210
# [16:55:40] ======== Monitor: updater_gpu_hist ========
# [16:55:40] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [16:55:40] ======== Monitor: SketchContainer ========
# [16:55:40] MakeCuts: 0.001039s, 1 calls @ 1039us
#
# [16:55:40] Prune: 0.000641s, 1 calls @ 641us
#
# [16:55:40] ScanInput: 0.000476s, 1 calls @ 476us
#
# [16:55:40] Unique: 0.000358s, 1 calls @ 358us
#
# [0]	validation_0-rmse:0.34872
# [1]	validation_0-rmse:0.24410
# [2]	validation_0-rmse:0.17087
# [3]	validation_0-rmse:0.11961
# [4]	validation_0-rmse:0.08373
# [5]	validation_0-rmse:0.05861
# [6]	validation_0-rmse:0.04103
# [7]	validation_0-rmse:0.02872
# [8]	validation_0-rmse:0.02011
# [9]	validation_0-rmse:0.01408
# [10]	validation_0-rmse:0.00986
# [11]	validation_0-rmse:0.00692
# [12]	validation_0-rmse:0.00486
# [13]	validation_0-rmse:0.00342
# [14]	validation_0-rmse:0.00243
# [15]	validation_0-rmse:0.00174
# [16]	validation_0-rmse:0.00128
# [17]	validation_0-rmse:0.00098
# [18]	validation_0-rmse:0.00078
# [19]	validation_0-rmse:0.00067
# [20]	validation_0-rmse:0.00061
# [21]	validation_0-rmse:0.00058
# [22]	validation_0-rmse:0.00056
# [23]	validation_0-rmse:0.00055
# [24]	validation_0-rmse:0.00055
# [25]	validation_0-rmse:0.00054
# [26]	validation_0-rmse:0.00054
# [27]	validation_0-rmse:0.00054
# [28]	validation_0-rmse:0.00054
# [29]	validation_0-rmse:0.00054
# [30]	validation_0-rmse:0.00054
# [31]	validation_0-rmse:0.00054
# [32]	validation_0-rmse:0.00054
# [33]	validation_0-rmse:0.00054
# [34]	validation_0-rmse:0.00054
# [35]	validation_0-rmse:0.00054
# [36]	validation_0-rmse:0.00054
# [37]	validation_0-rmse:0.00054
# [38]	validation_0-rmse:0.00054
# [39]	validation_0-rmse:0.00054
# [40]	validation_0-rmse:0.00054
# [41]	validation_0-rmse:0.00054
# [42]	validation_0-rmse:0.00054
# [43]	validation_0-rmse:0.00054
# [44]	validation_0-rmse:0.00054
# [45]	validation_0-rmse:0.00054
# [46]	validation_0-rmse:0.00054
# [47]	validation_0-rmse:0.00054
# [48]	validation_0-rmse:0.00054
# [49]	validation_0-rmse:0.00054
# [50]	validation_0-rmse:0.00054
# [16:55:40] ======== Monitor: Learner ========
# [16:55:40] Configure: 0.000909s, 1 calls @ 909us
#
# [16:55:40] EvalOneIter: 0.071781s, 52 calls @ 71781us
#
# [16:55:40] GetGradient: 0.011807s, 52 calls @ 11807us
#
# [16:55:40] PredictRaw: 0.00081s, 52 calls @ 810us
#
# [16:55:40] UpdateOneIter: 0.385839s, 52 calls @ 385839us
#
# [16:55:40] ======== Monitor: GBTree ========
# [16:55:40] BoostNewTrees: 0.36197s, 52 calls @ 361970us
#
# [16:55:40] CommitModel: 0.008502s, 52 calls @ 8502us
#
# [16:55:40] ======== Device 0 Memory Allocations:  ========
# [16:55:40] Peak memory usage: 40MiB
# [16:55:40] Number of allocations: 65565
# [16:55:40] ======== Monitor: updater_gpu_hist ========
# [16:55:40] InitData: 0.01994s, 52 calls @ 19940us
#
# [16:55:40] InitDataOnce: 0.019927s, 1 calls @ 19927us
#
# [16:55:40] Update: 0.361151s, 52 calls @ 361151us
#
# [16:55:40] UpdatePredictionCache: 0.008379s, 52 calls @ 8379us
#
# [16:55:40] ======== Monitor: gradient_based_sampler ========
# [16:55:40] Sample: 3.1e-05s, 52 calls @ 31us
#
# [16:55:40] ======== Monitor: GPUHistMakerDevice0 ========
# [16:55:40] AllReduce: 0.000159s, 805 calls @ 159us
#
# [16:55:40] BuildHist: 0.01352s, 753 calls @ 13520us
#
# [16:55:40] EvaluateSplits: 0.018191s, 753 calls @ 18191us
#
# [16:55:40] FinalisePosition: 0.005735s, 52 calls @ 5735us
#
# [16:55:40] InitRoot: 0.055238s, 52 calls @ 55238us
#
# [16:55:40] Reset: 0.030931s, 52 calls @ 30931us
#
# [16:55:40] UpdatePosition: 0.147644s, 753 calls @ 147644us
#
# [16:55:40] ======== Monitor: ellpack_page ========
# [16:55:40] BinningCompression: 0.004699s, 1 calls @ 4699us
#
# [16:55:40] InitCompressedData: 0.000126s, 1 calls @ 126us
#
# [16:55:40] Quantiles: 0.014923s, 1 calls @ 14923us
#
# Eval result: {'validation_0': OrderedDict([('rmse', [0.348722, 0.244104, 0.170871, 0.119609, 0.083726, 0.058609, 0.041027, 0.028721, 0.020108, 0.014081, 0.009864, 0.006915, 0.004856, 0.003421, 0.002426, 0.001742, 0.001279, 0.000976, 0.000785, 0.000672, 0.000609, 0.000576, 0.000559, 0.00055, 0.000546, 0.000543, 0.000542, 0.000542, 0.000541, 0.000541, 0.000541, 0.000541, 0.000541, 0.00054, 0.00054, 0.00054, 0.00054, 0.00054, 0.00054, 0.00054, 0.00054, 0.000539, 0.000539, 0.000539, 0.000539, 0.000539, 0.000539, 0.000539, 0.000539, 0.000539, 0.000539, 0.000539])])}
# [16:55:40] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [16:55:40] ======== Device 0 Memory Allocations:  ========
# [16:55:40] Peak memory usage: 40MiB
# [16:55:40] Number of allocations: 65565
# [16:55:40] ======== Monitor:  ========
# RMSPE Score: 0.24921
# Fold: 2
# 256014 85774
# [16:55:40] ======== Monitor: Learner ========
# [16:55:40] Configure: 0.000939s, 1 calls @ 939us
#
# [16:55:40] ======== Monitor: GBTree ========
# [16:55:40] ======== Device 0 Memory Allocations:  ========
# [16:55:40] Peak memory usage: 40MiB
# [16:55:40] Number of allocations: 65567
# [16:55:40] ======== Monitor: updater_gpu_hist ========
# [16:55:40] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [16:55:40] ======== Monitor: SketchContainer ========
# [16:55:40] MakeCuts: 0.001209s, 1 calls @ 1209us
#
# [16:55:40] Prune: 0.000767s, 1 calls @ 767us
#
# [16:55:40] ScanInput: 0.000549s, 1 calls @ 549us
#
# [16:55:40] Unique: 0.000379s, 1 calls @ 379us
#
# [0]	validation_0-rmse:0.34871
# [1]	validation_0-rmse:0.24410
# [2]	validation_0-rmse:0.17087
# [3]	validation_0-rmse:0.11961
# [4]	validation_0-rmse:0.08373
# [5]	validation_0-rmse:0.05861
# [6]	validation_0-rmse:0.04103
# [7]	validation_0-rmse:0.02873
# [8]	validation_0-rmse:0.02011
# [9]	validation_0-rmse:0.01409
# [10]	validation_0-rmse:0.00987
# [11]	validation_0-rmse:0.00692
# [12]	validation_0-rmse:0.00487
# [13]	validation_0-rmse:0.00343
# [14]	validation_0-rmse:0.00244
# [15]	validation_0-rmse:0.00176
# [16]	validation_0-rmse:0.00130
# [17]	validation_0-rmse:0.00100
# [18]	validation_0-rmse:0.00082
# [19]	validation_0-rmse:0.00071
# [20]	validation_0-rmse:0.00065
# [21]	validation_0-rmse:0.00062
# [22]	validation_0-rmse:0.00060
# [23]	validation_0-rmse:0.00059
# [24]	validation_0-rmse:0.00059
# [25]	validation_0-rmse:0.00059
# [26]	validation_0-rmse:0.00059
# [27]	validation_0-rmse:0.00058
# [28]	validation_0-rmse:0.00058
# [29]	validation_0-rmse:0.00058
# [30]	validation_0-rmse:0.00058
# [31]	validation_0-rmse:0.00058
# [32]	validation_0-rmse:0.00058
# [33]	validation_0-rmse:0.00058
# [34]	validation_0-rmse:0.00058
# [35]	validation_0-rmse:0.00058
# [36]	validation_0-rmse:0.00058
# [37]	validation_0-rmse:0.00058
# [38]	validation_0-rmse:0.00058
# [39]	validation_0-rmse:0.00058
# [40]	validation_0-rmse:0.00058
# [41]	validation_0-rmse:0.00058
# [42]	validation_0-rmse:0.00058
# [43]	validation_0-rmse:0.00058
# [44]	validation_0-rmse:0.00058
# [45]	validation_0-rmse:0.00058
# [46]	validation_0-rmse:0.00058
# [16:55:41] ======== Monitor: Learner ========
# [16:55:41] Configure: 0.000503s, 1 calls @ 503us
#
# [16:55:41] EvalOneIter: 0.060327s, 47 calls @ 60327us
#
# [16:55:41] GetGradient: 0.014334s, 47 calls @ 14334us
#
# [16:55:41] PredictRaw: 0.000634s, 47 calls @ 634us
#
# [16:55:41] UpdateOneIter: 0.348591s, 47 calls @ 348591us
#
# [16:55:41] ======== Monitor: GBTree ========
# [16:55:41] BoostNewTrees: 0.323934s, 47 calls @ 323934us
#
# [16:55:41] CommitModel: 0.007835s, 47 calls @ 7835us
#
# [16:55:41] ======== Device 0 Memory Allocations:  ========
# [16:55:41] Peak memory usage: 40MiB
# [16:55:41] Number of allocations: 71430
# [16:55:41] ======== Monitor: updater_gpu_hist ========
# [16:55:41] InitData: 0.023599s, 47 calls @ 23599us
#
# [16:55:41] InitDataOnce: 0.023588s, 1 calls @ 23588us
#
# [16:55:41] Update: 0.32334s, 47 calls @ 323340us
#
# [16:55:41] UpdatePredictionCache: 0.007733s, 47 calls @ 7733us
#
# [16:55:41] ======== Monitor: gradient_based_sampler ========
# [16:55:41] Sample: 1.8e-05s, 47 calls @ 18us
#
# [16:55:41] ======== Monitor: GPUHistMakerDevice0 ========
# [16:55:41] AllReduce: 0.000132s, 744 calls @ 132us
#
# [16:55:41] BuildHist: 0.011444s, 697 calls @ 11444us
#
# [16:55:41] EvaluateSplits: 0.014155s, 697 calls @ 14155us
#
# [16:55:41] FinalisePosition: 0.00536s, 47 calls @ 5360us
#
# [16:55:41] InitRoot: 0.051587s, 47 calls @ 51587us
#
# [16:55:41] Reset: 0.02513s, 47 calls @ 25130us
#
# [16:55:41] UpdatePosition: 0.128429s, 697 calls @ 128429us
#
# [16:55:41] ======== Monitor: ellpack_page ========
# [16:55:41] BinningCompression: 0.006107s, 1 calls @ 6107us
#
# [16:55:41] InitCompressedData: 0.000435s, 1 calls @ 435us
#
# [16:55:41] Quantiles: 0.016854s, 1 calls @ 16854us
#
# Eval result: {'validation_0': OrderedDict([('rmse', [0.348715, 0.2441, 0.170869, 0.119609, 0.083728, 0.058611, 0.041031, 0.028725, 0.020112, 0.014086, 0.00987, 0.006923, 0.004865, 0.003432, 0.002439, 0.001759, 0.001302, 0.001004, 0.000818, 0.00071, 0.00065, 0.000618, 0.000602, 0.000594, 0.00059, 0.000587, 0.000586, 0.000584, 0.000584, 0.000583, 0.000583, 0.000582, 0.000582, 0.000582, 0.000582, 0.000582, 0.000581, 0.000581, 0.000581, 0.000581, 0.000581, 0.000581, 0.000581, 0.000581, 0.000581, 0.000581, 0.000581])])}
# [16:55:41] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [16:55:41] ======== Device 0 Memory Allocations:  ========
# [16:55:41] Peak memory usage: 40MiB
# [16:55:41] Number of allocations: 71430
# [16:55:41] ======== Monitor:  ========
# RMSPE Score: 0.26326
# Fold: 3
# 341800 85776
# [16:55:41] ======== Monitor: Learner ========
# [16:55:41] Configure: 0.00123s, 1 calls @ 1230us
#
# [16:55:41] ======== Monitor: GBTree ========
# [16:55:41] ======== Device 0 Memory Allocations:  ========
# [16:55:41] Peak memory usage: 40MiB
# [16:55:41] Number of allocations: 71432
# [16:55:41] ======== Monitor: updater_gpu_hist ========
# [16:55:41] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [16:55:41] ======== Monitor: SketchContainer ========
# [16:55:41] MakeCuts: 0.000789s, 1 calls @ 789us
#
# [16:55:41] Prune: 0.000437s, 1 calls @ 437us
#
# [16:55:41] ScanInput: 0.000426s, 1 calls @ 426us
#
# [16:55:41] Unique: 0.000258s, 1 calls @ 258us
#
# [0]	validation_0-rmse:0.34877
# [1]	validation_0-rmse:0.24415
# [2]	validation_0-rmse:0.17097
# [3]	validation_0-rmse:0.11976
# [4]	validation_0-rmse:0.08396
# [5]	validation_0-rmse:0.05896
# [6]	validation_0-rmse:0.04154
# [7]	validation_0-rmse:0.02947
# [8]	validation_0-rmse:0.02117
# [9]	validation_0-rmse:0.01558
# [10]	validation_0-rmse:0.01193
# [11]	validation_0-rmse:0.00965
# [12]	validation_0-rmse:0.00831
# [13]	validation_0-rmse:0.00757
# [14]	validation_0-rmse:0.00718
# [15]	validation_0-rmse:0.00698
# [16]	validation_0-rmse:0.00688
# [17]	validation_0-rmse:0.00683
# [18]	validation_0-rmse:0.00681
# [19]	validation_0-rmse:0.00680
# [20]	validation_0-rmse:0.00679
# [21]	validation_0-rmse:0.00679
# [22]	validation_0-rmse:0.00679
# [23]	validation_0-rmse:0.00679
# [24]	validation_0-rmse:0.00679
# [25]	validation_0-rmse:0.00678
# [26]	validation_0-rmse:0.00678
# [27]	validation_0-rmse:0.00678
# [28]	validation_0-rmse:0.00678
# [29]	validation_0-rmse:0.00678
# [30]	validation_0-rmse:0.00678
# [31]	validation_0-rmse:0.00678
# [32]	validation_0-rmse:0.00678
# [33]	validation_0-rmse:0.00678
# [34]	validation_0-rmse:0.00678
# [35]	validation_0-rmse:0.00678
# [36]	validation_0-rmse:0.00678
# [37]	validation_0-rmse:0.00678
# [38]	validation_0-rmse:0.00678
# [39]	validation_0-rmse:0.00678
# [40]	validation_0-rmse:0.00678
# [41]	validation_0-rmse:0.00678
# [42]	validation_0-rmse:0.00678
# [43]	validation_0-rmse:0.00678
# [44]	validation_0-rmse:0.00678
# [16:55:42] ======== Monitor: Learner ========
# [16:55:42] Configure: 0.000454s, 1 calls @ 454us
#
# [16:55:42] EvalOneIter: 0.056331s, 45 calls @ 56331us
#
# [16:55:42] GetGradient: 0.012853s, 45 calls @ 12853us
#
# [16:55:42] PredictRaw: 0.000575s, 45 calls @ 575us
#
# [16:55:42] UpdateOneIter: 0.368613s, 45 calls @ 368613us
#
# [16:55:42] ======== Monitor: GBTree ========
# [16:55:42] BoostNewTrees: 0.344914s, 45 calls @ 344914us
#
# [16:55:42] CommitModel: 0.008514s, 45 calls @ 8514us
#
# [16:55:42] ======== Device 0 Memory Allocations:  ========
# [16:55:42] Peak memory usage: 40MiB
# [16:55:42] Number of allocations: 77017
# [16:55:42] ======== Monitor: updater_gpu_hist ========
# [16:55:42] InitData: 0.029719s, 45 calls @ 29719us
#
# [16:55:42] InitDataOnce: 0.029709s, 1 calls @ 29709us
#
# [16:55:42] Update: 0.344333s, 45 calls @ 344333us
#
# [16:55:42] UpdatePredictionCache: 0.008432s, 45 calls @ 8432us
#
# [16:55:42] ======== Monitor: gradient_based_sampler ========
# [16:55:42] Sample: 2e-05s, 45 calls @ 20us
#
# [16:55:42] ======== Monitor: GPUHistMakerDevice0 ========
# [16:55:42] AllReduce: 0.00012s, 708 calls @ 120us
#
# [16:55:42] BuildHist: 0.010037s, 663 calls @ 10037us
#
# [16:55:42] EvaluateSplits: 0.013331s, 663 calls @ 13331us
#
# [16:55:42] FinalisePosition: 0.006249s, 45 calls @ 6249us
#
# [16:55:42] InitRoot: 0.059083s, 45 calls @ 59083us
#
# [16:55:42] Reset: 0.029186s, 45 calls @ 29186us
#
# [16:55:42] UpdatePosition: 0.12679s, 663 calls @ 126790us
#
# [16:55:42] ======== Monitor: ellpack_page ========
# [16:55:42] BinningCompression: 0.008337s, 1 calls @ 8337us
#
# [16:55:42] InitCompressedData: 0.000478s, 1 calls @ 478us
#
# [16:55:42] Quantiles: 0.020729s, 1 calls @ 20729us
#
# Eval result: {'validation_0': OrderedDict([('rmse', [0.348774, 0.244153, 0.170965, 0.11976, 0.083958, 0.058957, 0.04154, 0.029466, 0.021175, 0.015583, 0.011926, 0.009645, 0.008306, 0.007566, 0.007177, 0.00698, 0.006883, 0.006832, 0.006809, 0.006798, 0.006792, 0.00679, 0.006789, 0.006788, 0.006788, 0.006783, 0.006781, 0.006781, 0.006781, 0.00678, 0.00678, 0.00678, 0.00678, 0.006779, 0.006776, 0.006776, 0.006776, 0.006776, 0.006777, 0.006777, 0.006777, 0.006777, 0.006777, 0.006777, 0.006777])])}
# [16:55:42] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [16:55:42] ======== Device 0 Memory Allocations:  ========
# [16:55:42] Peak memory usage: 40MiB
# [16:55:42] Number of allocations: 77017
# [16:55:42] ======== Monitor:  ========
# RMSPE Score: 3.19249
