# %% [markdown]
# # XGB FE & Opt/Tuning

# %% [markdown]
# This notebook offers:
#
# - new iterations of feature engineering
# - Param opt
# - CV scoring
#
# Credits to:
# - https://www.kaggle.com/manels/lgb-starter (initial feature eng and starting notebook for dataloading)
# - https://www.kaggle.com/ragnar123/optiver-realized-volatility-lgbm-baseline

# %%
import os, gc
import glob

from tqdm.notebook import tqdm
import pandas as pd
import numpy as np

from joblib import Parallel, delayed
from sklearn import preprocessing, model_selection

import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb

# %matplotlib inline

# %%
path_root = "./"
path_data = "./"

path_submissions = "./"

target_name = 'target'

# %%
train = pd.read_csv(os.path.join(path_data, 'train.csv'))

# %%
train.head()
# Out:
#    stock_id  time_id    target
# 0         0        5  0.004136
# 1         0       11  0.001445
# 2         0       16  0.002168
# 3         0       31  0.002195
# 4         0       62  0.001747

# %%
test = pd.read_csv(os.path.join(path_data,'test.csv'))

# %%
test.head()
# Out:
#    stock_id  time_id row_id
# 0         0        4    0-4
# 1         0       32   0-32
# 2         0       34   0-34

# %%
def log_return(list_stock_prices):
    return np.log(list_stock_prices).diff() 

def count_unique(series):
    return len(np.unique(series))

def realized_volatility(series_log_return):
    return np.sqrt(np.sum(series_log_return**2))

def rmspe(y_true, y_pred):
    return (np.sqrt(np.mean(np.square((y_true - y_pred)/y_true))))

def aggressor_side(series):
    return np.sign(series.diff())

def dollar_volume(df):
    return np.array(df['price'])*np.array(df['size'])

def signed_dollar_volume(df):
    side = aggressor_side(df)
    return np.array(df['dollar_volume'])*side

def kyle_lambda(df):
    diff = df['price'].diff().fillna(0)
    diff_sign = diff.apply(np.sign)
    diff_sign.replace(0,method='pad',inplace=True)
    signed_volume = df['size'] * diff_sign
#     print((diff / signed_volume).rolling(window=1).mean())
    return np.array((diff / signed_volume).rolling(window=1).mean())

def hasbrouck_lambda(log_ret, dollar_volume):
    log_ret_sign = log_ret.apply(np.sign).replace(0,method='pad')
    signed_dollar_volume_sqrt = np.sqrt(dollar_volume) * log_ret_sign
    
    return np.array((log_ret/signed_dollar_volume_sqrt).rolling(window=1).mean())

def vpin(volume, signed_buy_volume, window = 1):
    signed_sell_volume = volume - signed_buy_volume
    volume_imb = abs(signed_buy_volume - signed_sell_volume)
    return volume_imb.rolling(window=window).mean()/volume

# %%
def trade_preprocessor(file_path):
    df = pd.read_parquet(file_path)
    df['log_return'] = df.groupby('time_id')['price'].apply(log_return)
    
    df['side'] = np.sign(df['price'].diff())
    df['dollar_volume'] = df['price'] * df['size']
    df['signed_dollar_volume'] = df['dollar_volume'] * df['side']
    df['kyles'] = kyle_lambda(df)
    df['hasb'] = hasbrouck_lambda(df['log_return'],df['dollar_volume'])
    
    agg_dict = {
        'log_return':[realized_volatility],
        'size':[np.sum],
        'order_count':[np.mean],
        'dollar_volume':[np.sum],
        'signed_dollar_volume':[np.sum],
        'kyles':[np.mean],
        'hasb':[np.mean],
    }
    
    df_feature = df.groupby('time_id').agg(agg_dict)
    
    df_feature = df_feature.reset_index()
    df_feature.columns = ['_'.join(col) for col in df_feature.columns]
    
    df_feature = df_feature.add_prefix('trade_')
    stock_id = file_path.split('=')[1]
    df_feature['row_id'] = df_feature['trade_time_id_'].apply(lambda x:f'{stock_id}-{x}')
    df_feature = df_feature.drop(['trade_time_id_'],axis=1)
    
    return df_feature

# %%
file_path = os.path.join(path_data, 'trade_train.parquet/stock_id=0')
trade_preprocessor(file_path)
# Out:
# 0
#       trade_log_return_realized_volatility  trade_size_sum  \
# 0                                 0.002006            3179
# 1                                 0.000901            1289
# 2                                 0.001961            2161
# 3                                 0.001561            1962
# 4                                 0.000871            1791
# ...                                    ...             ...
# 3825                              0.001519            3450
# 3826                              0.001411            4547
# 3827                              0.001521            4250
# 3828                              0.001794            3217
# 3829                              0.001197            3679
#
#       trade_order_count_mean  trade_dollar_volume_sum  \
# 0                       2.75              3190.139181
# 1                        1.9              1289.353432
# 2                       2.72              2158.608928
# 3                   3.933333              1959.605547
# 4                   4.045455              1790.254496
# ...                      ...                      ...
# 3825                3.057692              3441.815546
# 3826                3.892857              4548.671493
# 3827                     3.5              4247.563002
# 3828                2.150943              3224.421796
# 3829                2.413793              3674.366695
#
#       trade_signed_dollar_volume_sum  trade_kyles_mean  trade_hasb_mean  \
# 0                         196.410613          0.000060         0.000096
# 1                         197.051910          0.000098         0.000051
# 2                       -1179.775465          0.000050         0.000090
# 3                        -307.434427          0.000026         0.000057
# 4                        -395.792862          0.000133         0.000056
# ...                              ...               ...              ...
# 3825                      120.949563          0.000040         0.000059
# 3826                      643.305188          0.000063         0.000087
# 3827                     1651.284059          0.000065         0.000035
# 3828                     -442.788901          0.000035         0.000053
# 3829                    -1046.118533          0.000031         0.000047
#
#        row_id
# 0         0-5
# 1        0-11
# 2        0-16
# 3        0-31
# 4        0-62
# ...       ...
# 3825  0-32751
# 3826  0-32753
# 3827  0-32758
# 3828  0-32763
# 3829  0-32767
#
# [3830 rows x 8 columns]

# %%
def book_preprocessor(file_path):
    df_book = pd.read_parquet(file_path)
    df_book['wap1'] = (df_book['bid_price1'] * df_book['ask_size1'] +
                                    df_book['ask_price1'] * df_book['bid_size1']) / (df_book['bid_size1'] + df_book['ask_size1'])
    df_book['wap2'] = (df_book['bid_price2'] * df_book['ask_size2'] +
                                    df_book['ask_price2'] * df_book['bid_size2']) / (df_book['bid_size2'] + df_book['ask_size2'])
    
    df_book['log_return1'] = df_book.groupby(by = ['time_id'])['wap1'].apply(log_return).fillna(0)
    df_book['log_return2'] = df_book.groupby(by = ['time_id'])['wap2'].apply(log_return).fillna(0)
    df_book['volume'] = (df_book['ask_size1'] + df_book['ask_size2']) + (df_book['bid_size1'] + df_book['bid_size2'])
    df_book['volume_imbalance'] = (df_book['ask_size1'] + df_book['ask_size2']) - (df_book['bid_size1'] + df_book['bid_size1'])
    
    agg_dict = {
        'log_return1':[realized_volatility],
        'log_return2':[realized_volatility],
        'volume':[np.sum],
        'volume_imbalance':[np.sum],
    }
    
    df_book = df_book.groupby(['time_id']).agg(agg_dict).reset_index()
    df_book.columns = ['_'.join(col) for col in df_book.columns]
    stock_id = file_path.split('=')[1]
    df_book['row_id'] = df_book['time_id_'].apply(lambda x:f'{stock_id}-{x}')
    df_book = df_book.drop(['time_id_'],axis=1)
    
    return df_book

# %%
def get_stock_data(stock_ids,training=True):
    df = pd.DataFrame()
    
    def for_joblib(stock_id):
        if training:
            dataType = 'train'
            file_path_book = os.path.join(path_data, 'book_{}.parquet/stock_id={}'.format(dataType, stock_id))
            file_path_trade = os.path.join(path_data,'trade_{}.parquet/stock_id={}'.format(dataType, stock_id))
        else:
            dataType = 'test'
            file_path_book = os.path.join(path_data, 'book_{}.parquet/stock_id={}'.format(dataType, stock_id))
            file_path_trade = os.path.join(path_data,'trade_{}.parquet/stock_id={}'.format(dataType, stock_id))
            
        df_tmp = pd.merge(book_preprocessor(file_path_book),trade_preprocessor(file_path_trade),on='row_id',how='left')
        
        
        return pd.concat([df,df_tmp])
    
    
    df = Parallel(n_jobs=-1,verbose=1)(
            delayed(for_joblib)(stock_id) for stock_id in stock_ids
        )
            
        
    df = pd.concat(df,ignore_index=True)
    
    return df

# %%
stock_ids = [0,1]
get_stock_data(stock_ids)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.7s finished
#       log_return1_realized_volatility  log_return2_realized_volatility  \
# 0                            0.004499                         0.006999
# 1                            0.001204                         0.002476
# 2                            0.002369                         0.004801
# 3                            0.002574                         0.003637
# 4                            0.001894                         0.003257
# ...                               ...                              ...
# 7655                         0.003723                         0.004996
# 7656                         0.010829                         0.012168
# 7657                         0.003135                         0.004268
# 7658                         0.003750                         0.005773
# 7659                         0.001681                         0.002399
#
#       volume_sum  volume_imbalance_sum   row_id  \
# 0          97696                  2362      0-5
# 1          82290                -26778     0-11
# 2          78274                  2524     0-16
# 3          52232                  2773     0-31
# 4          60407                -18320     0-62
# ...          ...                   ...      ...
# 7655       90929                  1075  1-32751
# 7656      280513                 47142  1-32753
# 7657      133527                -27629  1-32758
# 7658      228422                 10994  1-32763
# 7659      217629                  7783  1-32767
#
#       trade_log_return_realized_volatility  trade_size_sum  \
# 0                                 0.002006            3179
# 1                                 0.000901            1289
# 2                                 0.001961            2161
# 3                                 0.001561            1962
# 4                                 0.000871            1791
# ...                                    ...             ...
# 7655                              0.001776            3249
# 7656                              0.008492           75903
# 7657                              0.001927            2239
# 7658                              0.002856           16648
# 7659                              0.001704            7478
#
#       trade_order_count_mean  trade_dollar_volume_sum  \
# 0                       2.75              3190.139181
# 1                        1.9              1289.353432
# 2                       2.72              2158.608928
# 3                   3.933333              1959.605547
# 4                   4.045455              1790.254496
# ...                      ...                      ...
# 7655                 2.77551              3248.982168
# 7656                7.874317             76486.652579
# 7657                2.615385              2240.755934
# 7658                 2.93578             16696.638857
# 7659                2.073171              7478.224075
#
#       trade_signed_dollar_volume_sum  trade_kyles_mean  trade_hasb_mean
# 0                         196.410613          0.000060         0.000096
# 1                         197.051910          0.000098         0.000051
# 2                       -1179.775465          0.000050         0.000090
# 3                        -307.434427          0.000026         0.000057
# 4                        -395.792862          0.000133         0.000056
# ...                              ...               ...              ...
# 7655                     -432.521806          0.000053         0.000076
# 7656                    18669.938909          0.000018         0.000049
# 7657                     -206.603570          0.000023         0.000056
# 7658                    -1089.288566          0.000017         0.000039
# 7659                     1500.846459          0.000097         0.000082
#
# [7660 rows x 12 columns]

# %%
def feval_RMSPE(preds, train_data):
    labels = train_data.get_label()
    return 'RMSPE', round(rmspe(y_true = labels, y_pred = preds),5), False

# %%
train_ids = train.stock_id.unique()

# %%
# %%time
df_train=get_stock_data(train_ids)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.0s
# Wall time: 1min 59s
# [Parallel(n_jobs=-1)]: Done 112 out of 112 | elapsed:  2.0min finished

# %%
train['row_id'] = train['stock_id'].astype(str) +'-' +train['time_id'].astype(str)

train = train[['row_id','target']]

df_train = train.merge(df_train,on=['row_id'],how='left')

# %%
df_train.head()
# Out:
#   row_id    target  log_return1_realized_volatility  \
# 0    0-5  0.004136                         0.004499
# 1   0-11  0.001445                         0.001204
# 2   0-16  0.002168                         0.002369
# 3   0-31  0.002195                         0.002574
# 4   0-62  0.001747                         0.001894
#
#    log_return2_realized_volatility  volume_sum  volume_imbalance_sum  \
# 0                         0.006999       97696                  2362
# 1                         0.002476       82290                -26778
# 2                         0.004801       78274                  2524
# 3                         0.003637       52232                  2773
# 4                         0.003257       60407                -18320
#
#    trade_log_return_realized_volatility  trade_size_sum  \
# 0                              0.002006          3179.0
# 1                              0.000901          1289.0
# 2                              0.001961          2161.0
# 3                              0.001561          1962.0
# 4                              0.000871          1791.0
#
#    trade_order_count_mean  trade_dollar_volume_sum  \
# 0                    2.75              3190.139181
# 1                     1.9              1289.353432
# 2                    2.72              2158.608928
# 3                3.933333              1959.605547
# 4                4.045455              1790.254496
#
#    trade_signed_dollar_volume_sum  trade_kyles_mean  trade_hasb_mean
# 0                      196.410613          0.000060         0.000096
# 1                      197.051910          0.000098         0.000051
# 2                    -1179.775465          0.000050         0.000090
# 3                     -307.434427          0.000026         0.000057
# 4                     -395.792862          0.000133         0.000056

# %%
df_train.to_csv('./processed_train.csv')

# %%
test_ids = test.stock_id.unique()

# %%
# %%time
df_test = get_stock_data(test_ids, training=False)
# Out:
# Wall time: 63 ms
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %%
df_test = test.merge(df_test,on=['row_id'],how='left')

# %%
df_train['stock_id'] = df_train['row_id'].apply(lambda x:x.split('-')[0])
df_test['stock_id'] = df_test['row_id'].apply(lambda x:x.split('-')[0])


stock_id_target_mean = df_train.groupby('stock_id')['target'].mean()
df_test['stock_id_target_enc'] = df_test['stock_id'].map(stock_id_target_mean)

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=10,shuffle=True,random_state=729201)

tmp = np.repeat(np.nan,df_train.shape[0])

for idx1, idx2 in kf.split(df_train):
    target_mean = df_train.iloc[idx1].groupby('stock_id')['target'].mean()
    tmp[idx2] = df_train['stock_id'].iloc[idx2].map(target_mean)
    
df_train['stock_id_target_enc'] = tmp

# %%
df_train.head()
# Out:
#   row_id    target  log_return1_realized_volatility  \
# 0    0-5  0.004136                         0.004499
# 1   0-11  0.001445                         0.001204
# 2   0-16  0.002168                         0.002369
# 3   0-31  0.002195                         0.002574
# 4   0-62  0.001747                         0.001894
#
#    log_return2_realized_volatility  volume_sum  volume_imbalance_sum  \
# 0                         0.006999       97696                  2362
# 1                         0.002476       82290                -26778
# 2                         0.004801       78274                  2524
# 3                         0.003637       52232                  2773
# 4                         0.003257       60407                -18320
#
#    trade_log_return_realized_volatility  trade_size_sum  \
# 0                              0.002006          3179.0
# 1                              0.000901          1289.0
# 2                              0.001961          2161.0
# 3                              0.001561          1962.0
# 4                              0.000871          1791.0
#
#    trade_order_count_mean  trade_dollar_volume_sum  \
# 0                    2.75              3190.139181
# 1                     1.9              1289.353432
# 2                    2.72              2158.608928
# 3                3.933333              1959.605547
# 4                4.045455              1790.254496
#
#    trade_signed_dollar_volume_sum  trade_kyles_mean  trade_hasb_mean stock_id  \
# 0                      196.410613          0.000060         0.000096        0
# 1                      197.051910          0.000098         0.000051        0
# 2                    -1179.775465          0.000050         0.000090        0
# 3                     -307.434427          0.000026         0.000057        0
# 4                     -395.792862          0.000133         0.000056        0
#
#    stock_id_target_enc
# 0             0.004026
# 1             0.004022
# 2             0.003997
# 3             0.004034
# 4             0.004026

# %%
df_train.tail()
# Out:
#            row_id    target  log_return1_realized_volatility  \
# 428927  126-32751  0.003461                         0.003691
# 428928  126-32753  0.003113                         0.004104
# 428929  126-32758  0.004070                         0.003118
# 428930  126-32763  0.003357                         0.003661
# 428931  126-32767  0.002090                         0.002091
#
#         log_return2_realized_volatility  volume_sum  volume_imbalance_sum  \
# 428927                         0.005876      125874                -41748
# 428928                         0.004991       54261                -28823
# 428929                         0.006019       89112                -79205
# 428930                         0.005362      170140                 32288
# 428931                         0.003037      115295                   -55
#
#         trade_log_return_realized_volatility  trade_size_sum  \
# 428927                              0.002171          2570.0
# 428928                              0.002180          2323.0
# 428929                              0.001921          3740.0
# 428930                              0.002051          9389.0
# 428931                              0.001041          5325.0
#
#         trade_order_count_mean  trade_dollar_volume_sum  \
# 428927                2.783784              2568.838117
# 428928                3.418605              2327.828627
# 428929                     2.8              3742.254714
# 428930                   2.925              9406.795437
# 428931                     3.0              5326.415054
#
#         trade_signed_dollar_volume_sum  trade_kyles_mean  trade_hasb_mean  \
# 428927                      -14.933751          0.000085         0.000091
# 428928                      141.639961          0.000057         0.000088
# 428929                    -2102.770354          0.000052         0.000084
# 428930                     2209.567113          0.000029         0.000048
# 428931                    -2655.876849          0.000006         0.000017
#
#        stock_id  stock_id_target_enc
# 428927      126             0.005317
# 428928      126             0.005329
# 428929      126             0.005331
# 428930      126             0.005320
# 428931      126             0.005320

# %%
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args

# modified code for group gaps; source
# https://github.com/getgaurav2/scikit-learn/blob/d4a3af5cc9da3a76f0266932644b884c99724c57/sklearn/model_selection/_split.py#L2243
class PurgedGroupTimeSeriesSplit(_BaseKFold):
    """Time Series cross-validator variant with non-overlapping groups.
    Allows for a gap in groups to avoid potentially leaking info from
    train into test if the model has windowed or lag features.
    Provides train/test indices to split time series data samples
    that are observed at fixed time intervals according to a
    third-party provided group.
    In each split, test indices must be higher than before, and thus shuffling
    in cross validator is inappropriate.
    This cross-validation object is a variation of :class:`KFold`.
    In the kth split, it returns first k folds as train set and the
    (k+1)th fold as test set.
    The same group will not appear in two different folds (the number of
    distinct groups has to be at least equal to the number of folds).
    Note that unlike standard cross-validation methods, successive
    training sets are supersets of those that come before them.
    Read more in the :ref:`User Guide <cross_validation>`.
    Parameters
    ----------
    n_splits : int, default=5
        Number of splits. Must be at least 2.
    max_train_group_size : int, default=Inf
        Maximum group size for a single training set.
    group_gap : int, default=None
        Gap between train and test
    max_test_group_size : int, default=Inf
        We discard this number of groups from the end of each train split
    """

    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_group_size=np.inf,
                 max_test_group_size=np.inf,
                 group_gap=None,
                 verbose=False
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_group_size = max_train_group_size
        self.group_gap = group_gap
        self.max_test_group_size = max_test_group_size
        self.verbose = verbose

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        group_gap = self.group_gap
        max_test_group_size = self.max_test_group_size
        max_train_group_size = self.max_train_group_size
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))

        group_test_size = min(n_groups // n_folds, max_test_group_size)
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []

            group_st = max(0, group_test_start - group_gap - max_train_group_size)
            for train_group_idx in unique_groups[group_st:(group_test_start - group_gap)]:
                train_array_tmp = group_dict[train_group_idx]
                
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)

            train_end = train_array.size
 
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)

            test_array  = test_array[group_gap:]
            
            
            if self.verbose > 0:
                    pass
                    
            yield [int(i) for i in train_array], [int(i) for i in test_array]

# %%
df_train['stock_id'] = df_train['stock_id'].astype(int)
df_test['stock_id'] = df_test['stock_id'].astype(int)

# %%
df_train['trade_order_count_mean'] = df_train['trade_order_count_mean'].astype('float')

# %%
X = df_train.drop(['row_id','target'],axis=1)
y = df_train['target']

# %%
groupedKFold = PurgedGroupTimeSeriesSplit(n_splits=4, group_gap=12)
split = list(groupedKFold.split(df_train['target'],groups=df_train['stock_id'].values))

# %%
out_of_fold = pd.DataFrame()
models = []
scores = 0.0

# %%
model_name = 'xgb1'
pred_name = f'pred_{model_name}'


for _fold, (tr,te) in enumerate(split):
    print(f'Fold: {_fold}')
    
    trainSet_X = X.loc[tr]
    trainSet_Y = y.loc[tr]
    
    valSet_X = X.loc[te]
    valSet_Y = y.loc[te]
    
    weights = (1/np.square(trainSet_Y))
    valWeights = (1/np.square(valSet_Y))
    params = {'tree_method':'gpu_hist','reg_alpha' : 20, 'reg_lambda' : 20, 'max_depth' : 5, 'n_estimators' : 500,'verbosity': 3,}
    model = xgb.XGBRegressor(**params)
    
    model.fit(trainSet_X, trainSet_Y,
             eval_set=[(valSet_X,valSet_Y)],
             early_stopping_rounds=10, sample_weight=weights,
              sample_weight_eval_set=[valWeights],verbose=True
             )
    print(f'Eval result: {model.evals_result()}')
    
    preds = model.predict(valSet_X)
    RMPSE = round(rmspe(valSet_Y,preds),3)
    print(f'Model score: {RMPSE}')
    scores += RMPSE/4
# Out:
# Fold: 0
# [18:12:00] ======== Monitor: Learner ========
# [18:12:00] Configure: 0.00099s, 1 calls @ 990us
#
# [18:12:00] ======== Monitor: GBTree ========
# [18:12:00] ======== Device 0 Memory Allocations:  ========
# [18:12:00] Peak memory usage: 125MiB
# [18:12:00] Number of allocations: 6920919
# [18:12:00] ======== Monitor: updater_gpu_hist ========
# [18:12:00] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [18:12:00] ======== Monitor: SketchContainer ========
# [18:12:00] MakeCuts: 0.000981s, 1 calls @ 981us
#
# [18:12:00] Prune: 0.000624s, 1 calls @ 624us
#
# [18:12:00] ScanInput: 0.000732s, 1 calls @ 732us
#
# [18:12:00] Unique: 0.000443s, 1 calls @ 443us
#
# [0]	validation_0-rmse:0.34908
# [1]	validation_0-rmse:0.24442
# [2]	validation_0-rmse:0.17115
# [3]	validation_0-rmse:0.11987
# [4]	validation_0-rmse:0.08396
# [5]	validation_0-rmse:0.05883
# [6]	validation_0-rmse:0.04121
# [7]	validation_0-rmse:0.02890
# [8]	validation_0-rmse:0.02027
# [9]	validation_0-rmse:0.01426
# [10]	validation_0-rmse:0.01005
# [11]	validation_0-rmse:0.00713
# [12]	validation_0-rmse:0.00506
# [13]	validation_0-rmse:0.00365
# [14]	validation_0-rmse:0.00265
# [15]	validation_0-rmse:0.00198
# [16]	validation_0-rmse:0.00154
# [17]	validation_0-rmse:0.00128
# [18]	validation_0-rmse:0.00109
# [19]	validation_0-rmse:0.00096
# [20]	validation_0-rmse:0.00088
# [21]	validation_0-rmse:0.00083
# [22]	validation_0-rmse:0.00080
# [23]	validation_0-rmse:0.00079
# [24]	validation_0-rmse:0.00077
# [25]	validation_0-rmse:0.00077
# [26]	validation_0-rmse:0.00077
# [27]	validation_0-rmse:0.00076
# [28]	validation_0-rmse:0.00076
# [29]	validation_0-rmse:0.00077
# [30]	validation_0-rmse:0.00077
# [31]	validation_0-rmse:0.00078
# [32]	validation_0-rmse:0.00078
# [33]	validation_0-rmse:0.00078
# [34]	validation_0-rmse:0.00078
# [35]	validation_0-rmse:0.00078
# [36]	validation_0-rmse:0.00080
# [37]	validation_0-rmse:0.00080
# [38]	validation_0-rmse:0.00079
# [18:12:00] ======== Monitor: Learner ========
# [18:12:00] Configure: 0.000405s, 1 calls @ 405us
#
# [18:12:00] EvalOneIter: 0.061031s, 39 calls @ 61031us
#
# [18:12:00] GetGradient: 0.004901s, 39 calls @ 4901us
#
# [18:12:00] PredictRaw: 0.00042s, 39 calls @ 420us
#
# [18:12:00] UpdateOneIter: 0.247042s, 39 calls @ 247042us
#
# [18:12:00] ======== Monitor: GBTree ========
# [18:12:00] BoostNewTrees: 0.236611s, 39 calls @ 236611us
#
# [18:12:00] CommitModel: 0.003818s, 39 calls @ 3818us
#
# [18:12:00] ======== Device 0 Memory Allocations:  ========
# [18:12:00] Peak memory usage: 125MiB
# [18:12:00] Number of allocations: 6925621
# [18:12:00] ======== Monitor: updater_gpu_hist ========
# [18:12:00] InitData: 0.015181s, 39 calls @ 15181us
#
# [18:12:00] InitDataOnce: 0.015176s, 1 calls @ 15176us
#
# [18:12:00] Update: 0.236189s, 39 calls @ 236189us
#
# [18:12:00] UpdatePredictionCache: 0.003756s, 39 calls @ 3756us
#
# [18:12:00] ======== Monitor: gradient_based_sampler ========
# [18:12:00] Sample: 1.2e-05s, 39 calls @ 12us
#
# [18:12:00] ======== Monitor: GPUHistMakerDevice0 ========
# [18:12:00] AllReduce: 0.000102s, 593 calls @ 102us
#
# [18:12:00] BuildHist: 0.00802s, 554 calls @ 8020us
#
# [18:12:00] EvaluateSplits: 0.009456s, 554 calls @ 9456us
#
# [18:12:00] FinalisePosition: 0.003125s, 39 calls @ 3125us
#
# [18:12:00] InitRoot: 0.033199s, 39 calls @ 33199us
#
# [18:12:00] Reset: 0.019832s, 39 calls @ 19832us
#
# [18:12:00] UpdatePosition: 0.103647s, 554 calls @ 103647us
#
# [18:12:00] ======== Monitor: ellpack_page ========
# [18:12:00] BinningCompression: 0.003048s, 1 calls @ 3048us
#
# [18:12:00] InitCompressedData: 7.9e-05s, 1 calls @ 79us
#
# [18:12:00] Quantiles: 0.011909s, 1 calls @ 11909us
#
# Eval result: {'validation_0': OrderedDict([('rmse', [0.349083, 0.244421, 0.171153, 0.119866, 0.083962, 0.058826, 0.041213, 0.028897, 0.020268, 0.014255, 0.010045, 0.007133, 0.005064, 0.003646, 0.002653, 0.001979, 0.001536, 0.001278, 0.001086, 0.000958, 0.000878, 0.000829, 0.000804, 0.000787, 0.000774, 0.000766, 0.000767, 0.000765, 0.000763, 0.000766, 0.000766, 0.00078, 0.000779, 0.000779, 0.000778, 0.000779, 0.000795, 0.000796, 0.000794])])}
# [18:12:00] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [18:12:00] ======== Device 0 Memory Allocations:  ========
# [18:12:00] Peak memory usage: 125MiB
# [18:12:00] Number of allocations: 6925621
# [18:12:00] ======== Monitor:  ========
# Model score: 0.438
# Fold: 1
# [18:12:00] ======== Monitor: Learner ========
# [18:12:00] Configure: 0.001043s, 1 calls @ 1043us
#
# [18:12:00] ======== Monitor: GBTree ========
# [18:12:00] ======== Device 0 Memory Allocations:  ========
# [18:12:00] Peak memory usage: 125MiB
# [18:12:00] Number of allocations: 6925623
# [18:12:00] ======== Monitor: updater_gpu_hist ========
# [18:12:00] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [18:12:00] ======== Monitor: SketchContainer ========
# [18:12:00] MakeCuts: 0.000854s, 1 calls @ 854us
#
# [18:12:00] Prune: 0.000552s, 1 calls @ 552us
#
# [18:12:00] ScanInput: 0.000656s, 1 calls @ 656us
#
# [18:12:00] Unique: 0.00037s, 1 calls @ 370us
#
# [0]	validation_0-rmse:0.34866
# [1]	validation_0-rmse:0.24406
# [2]	validation_0-rmse:0.17084
# [3]	validation_0-rmse:0.11958
# [4]	validation_0-rmse:0.08371
# [5]	validation_0-rmse:0.05859
# [6]	validation_0-rmse:0.04101
# [7]	validation_0-rmse:0.02871
# [8]	validation_0-rmse:0.02010
# [9]	validation_0-rmse:0.01407
# [10]	validation_0-rmse:0.00986
# [11]	validation_0-rmse:0.00691
# [12]	validation_0-rmse:0.00485
# [13]	validation_0-rmse:0.00342
# [14]	validation_0-rmse:0.00242
# [15]	validation_0-rmse:0.00173
# [16]	validation_0-rmse:0.00127
# [17]	validation_0-rmse:0.00096
# [18]	validation_0-rmse:0.00077
# [19]	validation_0-rmse:0.00066
# [20]	validation_0-rmse:0.00059
# [21]	validation_0-rmse:0.00056
# [22]	validation_0-rmse:0.00054
# [23]	validation_0-rmse:0.00054
# [24]	validation_0-rmse:0.00054
# [25]	validation_0-rmse:0.00053
# [26]	validation_0-rmse:0.00053
# [27]	validation_0-rmse:0.00053
# [28]	validation_0-rmse:0.00053
# [29]	validation_0-rmse:0.00053
# [30]	validation_0-rmse:0.00053
# [31]	validation_0-rmse:0.00053
# [32]	validation_0-rmse:0.00053
# [33]	validation_0-rmse:0.00053
# [34]	validation_0-rmse:0.00053
# [35]	validation_0-rmse:0.00053
# [36]	validation_0-rmse:0.00053
# [37]	validation_0-rmse:0.00053
# [38]	validation_0-rmse:0.00053
# [39]	validation_0-rmse:0.00053
# [40]	validation_0-rmse:0.00053
# [41]	validation_0-rmse:0.00053
# [42]	validation_0-rmse:0.00053
# [18:12:01] ======== Monitor: Learner ========
# [18:12:01] Configure: 0.000424s, 1 calls @ 424us
#
# [18:12:01] EvalOneIter: 0.064357s, 43 calls @ 64357us
#
# [18:12:01] GetGradient: 0.007026s, 43 calls @ 7026us
#
# [18:12:01] PredictRaw: 0.000476s, 43 calls @ 476us
#
# [18:12:01] UpdateOneIter: 0.321557s, 43 calls @ 321557us
#
# [18:12:01] ======== Monitor: GBTree ========
# [18:12:01] BoostNewTrees: 0.307732s, 43 calls @ 307732us
#
# [18:12:01] CommitModel: 0.004885s, 43 calls @ 4885us
#
# [18:12:01] ======== Device 0 Memory Allocations:  ========
# [18:12:01] Peak memory usage: 125MiB
# [18:12:01] Number of allocations: 6930986
# [18:12:01] ======== Monitor: updater_gpu_hist ========
# [18:12:01] InitData: 0.030677s, 43 calls @ 30677us
#
# [18:12:01] InitDataOnce: 0.030669s, 1 calls @ 30669us
#
# [18:12:01] Update: 0.307281s, 43 calls @ 307281us
#
# [18:12:01] UpdatePredictionCache: 0.00481s, 43 calls @ 4810us
#
# [18:12:01] ======== Monitor: gradient_based_sampler ========
# [18:12:01] Sample: 1.8e-05s, 43 calls @ 18us
#
# [18:12:01] ======== Monitor: GPUHistMakerDevice0 ========
# [18:12:01] AllReduce: 0.000111s, 680 calls @ 111us
#
# [18:12:01] BuildHist: 0.009044s, 637 calls @ 9044us
#
# [18:12:01] EvaluateSplits: 0.010569s, 637 calls @ 10569us
#
# [18:12:01] FinalisePosition: 0.005241s, 43 calls @ 5241us
#
# [18:12:01] InitRoot: 0.052837s, 43 calls @ 52837us
#
# [18:12:01] Reset: 0.020553s, 43 calls @ 20553us
#
# [18:12:01] UpdatePosition: 0.123587s, 637 calls @ 123587us
#
# [18:12:01] ======== Monitor: ellpack_page ========
# [18:12:01] BinningCompression: 0.007882s, 1 calls @ 7882us
#
# [18:12:01] InitCompressedData: 0.000366s, 1 calls @ 366us
#
# [18:12:01] Quantiles: 0.022233s, 1 calls @ 22233us
#
# Eval result: {'validation_0': OrderedDict([('rmse', [0.348664, 0.244061, 0.170839, 0.119585, 0.083706, 0.058592, 0.041014, 0.028713, 0.020101, 0.014071, 0.009857, 0.00691, 0.004851, 0.003415, 0.002419, 0.001733, 0.001269, 0.000964, 0.000771, 0.000658, 0.000594, 0.00056, 0.000542, 0.000542, 0.000537, 0.000534, 0.000532, 0.000532, 0.000531, 0.000531, 0.000531, 0.000531, 0.00053, 0.00053, 0.00053, 0.000531, 0.00053, 0.00053, 0.00053, 0.000531, 0.000531, 0.000531, 0.000531])])}
# [18:12:01] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [18:12:01] ======== Device 0 Memory Allocations:  ========
# [18:12:01] Peak memory usage: 125MiB
# [18:12:01] Number of allocations: 6930986
# [18:12:01] ======== Monitor:  ========
# Model score: 0.24
# Fold: 2
# [18:12:01] ======== Monitor: Learner ========
# [18:12:01] Configure: 0.001011s, 1 calls @ 1011us
#
# [18:12:01] ======== Monitor: GBTree ========
# [18:12:01] ======== Device 0 Memory Allocations:  ========
# [18:12:01] Peak memory usage: 125MiB
# [18:12:01] Number of allocations: 6930988
# [18:12:01] ======== Monitor: updater_gpu_hist ========
# [18:12:01] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [18:12:01] ======== Monitor: SketchContainer ========
# [18:12:01] MakeCuts: 0.000963s, 1 calls @ 963us
#
# [18:12:01] Prune: 0.000563s, 1 calls @ 563us
#
# [18:12:01] ScanInput: 0.000741s, 1 calls @ 741us
#
# [18:12:01] Unique: 0.000381s, 1 calls @ 381us
#
# [0]	validation_0-rmse:0.34848
# [1]	validation_0-rmse:0.24392
# [2]	validation_0-rmse:0.17073
# [3]	validation_0-rmse:0.11950
# [4]	validation_0-rmse:0.08364
# [5]	validation_0-rmse:0.05855
# [6]	validation_0-rmse:0.04098
# [7]	validation_0-rmse:0.02869
# [8]	validation_0-rmse:0.02010
# [9]	validation_0-rmse:0.01409
# [10]	validation_0-rmse:0.00989
# [11]	validation_0-rmse:0.00698
# [12]	validation_0-rmse:0.00492
# [13]	validation_0-rmse:0.00350
# [14]	validation_0-rmse:0.00252
# [15]	validation_0-rmse:0.00184
# [16]	validation_0-rmse:0.00142
# [17]	validation_0-rmse:0.00112
# [18]	validation_0-rmse:0.00093
# [19]	validation_0-rmse:0.00081
# [20]	validation_0-rmse:0.00074
# [21]	validation_0-rmse:0.00070
# [22]	validation_0-rmse:0.00068
# [23]	validation_0-rmse:0.00067
# [24]	validation_0-rmse:0.00066
# [25]	validation_0-rmse:0.00067
# [26]	validation_0-rmse:0.00067
# [27]	validation_0-rmse:0.00068
# [28]	validation_0-rmse:0.00068
# [29]	validation_0-rmse:0.00068
# [30]	validation_0-rmse:0.00068
# [31]	validation_0-rmse:0.00068
# [32]	validation_0-rmse:0.00068
# [33]	validation_0-rmse:0.00068
# [18:12:01] ======== Monitor: Learner ========
# [18:12:01] Configure: 0.0004s, 1 calls @ 400us
#
# [18:12:01] EvalOneIter: 0.050646s, 35 calls @ 50646us
#
# [18:12:01] GetGradient: 0.00716s, 35 calls @ 7160us
#
# [18:12:01] PredictRaw: 0.000418s, 35 calls @ 418us
#
# [18:12:01] UpdateOneIter: 0.305181s, 35 calls @ 305181us
#
# [18:12:01] ======== Monitor: GBTree ========
# [18:12:01] BoostNewTrees: 0.291753s, 35 calls @ 291753us
#
# [18:12:01] CommitModel: 0.004651s, 35 calls @ 4651us
#
# [18:12:01] ======== Device 0 Memory Allocations:  ========
# [18:12:01] Peak memory usage: 125MiB
# [18:12:01] Number of allocations: 6935344
# [18:12:01] ======== Monitor: updater_gpu_hist ========
# [18:12:01] InitData: 0.045145s, 35 calls @ 45145us
#
# [18:12:01] InitDataOnce: 0.045138s, 1 calls @ 45138us
#
# [18:12:01] Update: 0.291376s, 35 calls @ 291376us
#
# [18:12:01] UpdatePredictionCache: 0.004584s, 35 calls @ 4584us
#
# [18:12:01] ======== Monitor: gradient_based_sampler ========
# [18:12:01] Sample: 1.1e-05s, 35 calls @ 11us
#
# [18:12:01] ======== Monitor: GPUHistMakerDevice0 ========
# [18:12:01] AllReduce: 9.3e-05s, 551 calls @ 93us
#
# [18:12:01] BuildHist: 0.007362s, 516 calls @ 7362us
#
# [18:12:01] EvaluateSplits: 0.009039s, 516 calls @ 9039us
#
# [18:12:01] FinalisePosition: 0.00563s, 35 calls @ 5630us
#
# [18:12:01] InitRoot: 0.051453s, 35 calls @ 51453us
#
# [18:12:01] Reset: 0.017178s, 35 calls @ 17178us
#
# [18:12:01] UpdatePosition: 0.104986s, 516 calls @ 104986us
#
# [18:12:01] ======== Monitor: ellpack_page ========
# [18:12:01] BinningCompression: 0.012564s, 1 calls @ 12564us
#
# [18:12:01] InitCompressedData: 0.000491s, 1 calls @ 491us
#
# [18:12:01] Quantiles: 0.03193s, 1 calls @ 31930us
#
# Eval result: {'validation_0': OrderedDict([('rmse', [0.348484, 0.243924, 0.170733, 0.1195, 0.083643, 0.058546, 0.040982, 0.028694, 0.020101, 0.014092, 0.009892, 0.006979, 0.004925, 0.003496, 0.002521, 0.001842, 0.001423, 0.00112, 0.000925, 0.000812, 0.000741, 0.000701, 0.000676, 0.000673, 0.000664, 0.00067, 0.000666, 0.000679, 0.000677, 0.000679, 0.000678, 0.000677, 0.000677, 0.000676, 0.000676])])}
# [18:12:01] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [18:12:01] ======== Device 0 Memory Allocations:  ========
# [18:12:01] Peak memory usage: 125MiB
# [18:12:01] Number of allocations: 6935344
# [18:12:01] ======== Monitor:  ========
# Model score: 0.265
# Fold: 3
# [18:12:02] ======== Monitor: Learner ========
# [18:12:02] Configure: 0.000988s, 1 calls @ 988us
#
# [18:12:02] ======== Monitor: GBTree ========
# [18:12:02] ======== Device 0 Memory Allocations:  ========
# [18:12:02] Peak memory usage: 125MiB
# [18:12:02] Number of allocations: 6935346
# [18:12:02] ======== Monitor: updater_gpu_hist ========
# [18:12:02] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [18:12:02] ======== Monitor: SketchContainer ========
# [18:12:02] MakeCuts: 0.00092s, 1 calls @ 920us
#
# [18:12:02] Prune: 0.000574s, 1 calls @ 574us
#
# [18:12:02] ScanInput: 0.000773s, 1 calls @ 773us
#
# [18:12:02] Unique: 0.000394s, 1 calls @ 394us
#
# [0]	validation_0-rmse:0.34868
# [1]	validation_0-rmse:0.24407
# [2]	validation_0-rmse:0.17085
# [3]	validation_0-rmse:0.11959
# [4]	validation_0-rmse:0.08371
# [5]	validation_0-rmse:0.05860
# [6]	validation_0-rmse:0.04102
# [7]	validation_0-rmse:0.02872
# [8]	validation_0-rmse:0.02010
# [9]	validation_0-rmse:0.01408
# [10]	validation_0-rmse:0.00986
# [11]	validation_0-rmse:0.00691
# [12]	validation_0-rmse:0.00486
# [13]	validation_0-rmse:0.00343
# [14]	validation_0-rmse:0.00243
# [15]	validation_0-rmse:0.00174
# [16]	validation_0-rmse:0.00128
# [17]	validation_0-rmse:0.00097
# [18]	validation_0-rmse:0.00078
# [19]	validation_0-rmse:0.00067
# [20]	validation_0-rmse:0.00060
# [21]	validation_0-rmse:0.00057
# [22]	validation_0-rmse:0.00055
# [23]	validation_0-rmse:0.00054
# [24]	validation_0-rmse:0.00054
# [25]	validation_0-rmse:0.00054
# [26]	validation_0-rmse:0.00053
# [27]	validation_0-rmse:0.00053
# [28]	validation_0-rmse:0.00053
# [29]	validation_0-rmse:0.00053
# [30]	validation_0-rmse:0.00053
# [31]	validation_0-rmse:0.00053
# [32]	validation_0-rmse:0.00053
# [33]	validation_0-rmse:0.00053
# [34]	validation_0-rmse:0.00053
# [35]	validation_0-rmse:0.00053
# [36]	validation_0-rmse:0.00053
# [37]	validation_0-rmse:0.00053
# [38]	validation_0-rmse:0.00053
# [39]	validation_0-rmse:0.00053
# [40]	validation_0-rmse:0.00053
# [18:12:02] ======== Monitor: Learner ========
# [18:12:02] Configure: 0.000511s, 1 calls @ 511us
#
# [18:12:02] EvalOneIter: 0.057798s, 41 calls @ 57798us
#
# [18:12:02] GetGradient: 0.009667s, 41 calls @ 9667us
#
# [18:12:02] PredictRaw: 0.000736s, 41 calls @ 736us
#
# [18:12:02] UpdateOneIter: 0.410399s, 41 calls @ 410399us
#
# [18:12:02] ======== Monitor: GBTree ========
# [18:12:02] BoostNewTrees: 0.391802s, 41 calls @ 391802us
#
# [18:12:02] CommitModel: 0.006792s, 41 calls @ 6792us
#
# [18:12:02] ======== Device 0 Memory Allocations:  ========
# [18:12:02] Peak memory usage: 125MiB
# [18:12:02] Number of allocations: 6940424
# [18:12:02] ======== Monitor: updater_gpu_hist ========
# [18:12:02] InitData: 0.058421s, 41 calls @ 58421us
#
# [18:12:02] InitDataOnce: 0.058415s, 1 calls @ 58415us
#
# [18:12:02] Update: 0.391395s, 41 calls @ 391395us
#
# [18:12:02] UpdatePredictionCache: 0.006726s, 41 calls @ 6726us
#
# [18:12:02] ======== Monitor: gradient_based_sampler ========
# [18:12:02] Sample: 1.2e-05s, 41 calls @ 12us
#
# [18:12:02] ======== Monitor: GPUHistMakerDevice0 ========
# [18:12:02] AllReduce: 0.000105s, 643 calls @ 105us
#
# [18:12:02] BuildHist: 0.008554s, 602 calls @ 8554us
#
# [18:12:02] EvaluateSplits: 0.009718s, 602 calls @ 9718us
#
# [18:12:02] FinalisePosition: 0.008359s, 41 calls @ 8359us
#
# [18:12:02] InitRoot: 0.077246s, 41 calls @ 77246us
#
# [18:12:02] Reset: 0.020141s, 41 calls @ 20141us
#
# [18:12:02] UpdatePosition: 0.134025s, 602 calls @ 134025us
#
# [18:12:02] ======== Monitor: ellpack_page ========
# [18:12:02] BinningCompression: 0.016091s, 1 calls @ 16091us
#
# [18:12:02] InitCompressedData: 0.000485s, 1 calls @ 485us
#
# [18:12:02] Quantiles: 0.041661s, 1 calls @ 41661us
#
# Eval result: {'validation_0': OrderedDict([('rmse', [0.34868, 0.244073, 0.170851, 0.119594, 0.083711, 0.058597, 0.041021, 0.028716, 0.020104, 0.014079, 0.009862, 0.006914, 0.004858, 0.003425, 0.002429, 0.001743, 0.001276, 0.000973, 0.000781, 0.000668, 0.000602, 0.000568, 0.000551, 0.000543, 0.000538, 0.000536, 0.000535, 0.000534, 0.000534, 0.000534, 0.000533, 0.000534, 0.000533, 0.000533, 0.000533, 0.000533, 0.000533, 0.000533, 0.000533, 0.000533, 0.000533])])}
# [18:12:02] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/tree/updater_gpu_hist.cu:892: [GPU Hist]: Configure
# [18:12:02] ======== Device 0 Memory Allocations:  ========
# [18:12:02] Peak memory usage: 125MiB
# [18:12:02] Number of allocations: 6940424
# [18:12:02] ======== Monitor:  ========
# Model score: 0.242

# %%
scores
# Out:
# 0.29625
